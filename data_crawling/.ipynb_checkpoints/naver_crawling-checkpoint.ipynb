# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
import re

# %%
def getNames(url):
    df = pd.read_html(requests.get(url).text)[2].loc[:, :'전일거래량']
    df = df[df.종목명.isna() == False]
    return [i for i in df.종목명]

# %%
def getIndustryData():
    url = 'https://finance.naver.com/sise/sise_group.nhn?type=upjong'
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    업종 = pd.read_html(html)[0].dropna().reset_index(drop=True)
    업종.columns = [i[1] for i in 업종.columns]
    업종링크 = {}
    for index, link in enumerate(soup.findAll("a", href=re.compile("^(/sise/sise_group_detail.nhn)((?!:).)*$"))):
        if 'href' in link.attrs:
            업종링크[업종.업종명[index]] = 'https://finance.naver.com' + link.attrs['href']
    업종['전일비'] = 업종.전일대비.apply(lambda x: float(x.replace('%', '')))
    업종['링크'] = 업종.업종명.apply(lambda x: 업종링크.get(x))
    업종['대표종목'] = 업종.링크.apply(lambda x: getNames(x))
    업종.sort_values('전일비', ascending=False, inplace=True)
    return pd.concat([업종.head(10), 업종.tail(10)])

# %%
getIndustryData()
# Out:
#              업종명    전일대비    전체   상승   보합    하락 등락그래프   전일비  \
# 0           가정용품  +5.16%   7.0  6.0  0.0   1.0   89%  5.16
# 1        디스플레이패널  +4.39%   2.0  2.0  0.0   0.0   76%  4.39
# 2             카드  +2.02%   1.0  1.0  0.0   0.0   35%  2.02
# 3             담배  +1.28%   1.0  1.0  0.0   0.0   22%  1.28
# 4          석유와가스  +0.89%  21.0  3.0  1.0  17.0   15%  0.89
# 5      상업서비스와공급품  +0.82%  23.0  8.0  1.0  14.0   14%  0.82
# 6           생명보험  +0.62%   5.0  3.0  1.0   1.0   10%  0.62
# 7           전문소매  +0.61%   4.0  2.0  1.0   1.0   10%  0.61
# 8          교육서비스  +0.58%  20.0  7.0  1.0  12.0   10%  0.58
# 9           손해보험  +0.40%  12.0  4.0  1.0   7.0    6%  0.40
# 69            음료  -2.78%  15.0  3.0  0.0  12.0   48% -2.78
# 70        건강관리기술  -2.88%   8.0  0.0  0.0   8.0   50% -2.88
# 71          전기제품  -3.61%  40.0  3.0  1.0  36.0   62% -3.61
# 72      레저용장비와제품  -3.65%   9.0  1.0  0.0   8.0   63% -3.65
# 73            출판  -3.67%   5.0  0.0  1.0   4.0   63% -3.67
# 74          통신장비  -4.38%  48.0  3.0  6.0  39.0   76% -4.38
# 75          건축제품  -4.75%  18.0  1.0  0.0  17.0   82% -4.75
# 76           문구류  -5.07%   3.0  0.0  0.0   3.0   88% -5.07
# 77  독립전력생산및에너지거래  -5.15%   1.0  0.0  0.0   1.0   89% -5.15
# 78    생명과학도구및서비스  -5.75%  25.0  0.0  1.0  24.0  100% -5.75
#
#                                                    링크  \
# 0   https://finance.naver.com/sise/sise_group_deta...
# 1   https://finance.naver.com/sise/sise_group_deta...
# 2   https://finance.naver.com/sise/sise_group_deta...
# 3   https://finance.naver.com/sise/sise_group_deta...
# 4   https://finance.naver.com/sise/sise_group_deta...
# 5   https://finance.naver.com/sise/sise_group_deta...
# 6   https://finance.naver.com/sise/sise_group_deta...
# 7   https://finance.naver.com/sise/sise_group_deta...
# 8   https://finance.naver.com/sise/sise_group_deta...
# 9   https://finance.naver.com/sise/sise_group_deta...
# 69  https://finance.naver.com/sise/sise_group_deta...
# 70  https://finance.naver.com/sise/sise_group_deta...
# 71  https://finance.naver.com/sise/sise_group_deta...
# 72  https://finance.naver.com/sise/sise_group_deta...
# 73  https://finance.naver.com/sise/sise_group_deta...
# 74  https://finance.naver.com/sise/sise_group_deta...
# 75  https://finance.naver.com/sise/sise_group_deta...
# 76  https://finance.naver.com/sise/sise_group_deta...
# 77  https://finance.naver.com/sise/sise_group_deta...
# 78  https://finance.naver.com/sise/sise_group_deta...
#
#                                                  대표종목
# 0   [모나리자, 메디앙스 *, 바이오제네틱스 *, 애경산업, 삼정펄프, 태양 *, 케이...
# 1                                    [LG디스플레이, 일진디스플]
# 2                                              [삼성카드]
# 3                                              [KT&G]
# 4   [SK이노베이션, S-Oil, SK이노베이션우, 에스아이리소스 *, S-Oil우, ...
# 5   [NICE평가정보 *, NICE, 한국기업평가 *, 아이마켓코리아, 제넨바이오 *,...
# 6                  [미래에셋생명, 동양생명, 삼성생명, 오렌지라이프, 한화생명]
# 7                 [롯데하이마트, 도이치모터스 *, 포스링크 *, 씨유메디칼 *]
# 8   [메가엠디 *, 아이스크림에듀 *, 이퓨쳐 *, NE능률 *, 메가스터디교육 *, ...
# 9   [메리츠금융지주, 흥국화재, 메리츠화재, 삼성화재, 삼성화재우, 흥국화재우, DB손...
# 69  [MH에탄올, 롯데칠성, 무학, 롯데칠성우, 진로발효 *, 하이트진로2우B, 흥국에...
# 70  [비트컴퓨터 *, 이지케어텍 *, 인피니트헬스케어 *, 솔본 *, 유비케어 *, 케...
# 71  [디피씨, 비츠로셀 *, 성호전자 *, 크로바하이텍 *, 서울전자통신 *, 필룩스,...
# 72  [알톤스포츠 *, 이녹스 *, 삼천리자전거 *, 헝셩그룹 *, 오로라 *, 손오공 ...
# 73     [한류타임즈 *, 미스터블루 *, 디지틀조선 *, 아시아경제 *, 디앤씨미디어 *]
# 74  [아이크래프트 *, 파이오링크 *, 현대통신 *, 모다 *, 감마누 *, 폴루스바이...
# 75  [대림통상, 금강공업우, 제일테크노스 *, 와토스코리아 *, 대림B&Co, 삼목에스...
# 76                                [모나미, 양지사 *, 삼성출판사]
# 77                                          [에코바이오 *]
# 78  [캔서롭 *, 서흥, 엔케이맥스 *, 켐온 *, 레고켐바이오 *, 크리스탈 *, 디...

# %%
def getThemeDataPages(pageNums):
    themes = pd.DataFrame()
    linkDict = {}
    
    for pageNum in pageNums:
        url = f'https://finance.naver.com/sise/theme.nhn?&page={pageNum}'
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        
        df = pd.read_html(html)[0].reset_index(drop=True)
        df.columns = [i[1] for i in df.columns]
        df = df[df.테마명.isna() == False]
        themes = pd.concat([themes, df])
        
        # findLink
        for link in soup.findAll("a", href=re.compile("^(/sise/sise_group_detail.nhn)((?!:).)*$")):
            if 'href' in link.attrs:
                    linkDict[link.text] = 'https://finance.naver.com' + link.attrs['href']
        
    themes = themes.reset_index(drop=True)
    themes['링크'] = themes.테마명.apply(lambda x: linkDict.get(x))
    
    return themes

# %%
def getThemeData():
    url = 'https://finance.naver.com/sise/theme.nhn?&page=1'
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')

    pageNums = pd.read_html(html)[1].columns[1:]
    
    df = getThemeDataPages(pageNums)
    df['종목'] = df.링크.apply(lambda x: getNames(x))
    summary = pd.concat([df.head(10), df.tail(10)])
    return summary, df

# %%
summary, df = getThemeData()

# %%
df[df.테마명 == '황사/미세먼지'].종목.tolist()
# Out:
# [['웰크론 *',
#   '모나리자',
#   '오공 *',
#   '케이엠 *',
#   '휴비츠 *',
#   '크린앤사이언스 *',
#   'JW중외제약',
#   '포스코 ICT *',
#   '국제약품',
#   '롯데하이마트',
#   '한국테크놀로지 *',
#   '비디아이 *',
#   '웅진코웨이',
#   '락앤락',
#   '파세코 *',
#   '누리플랜 *',
#   '나노 *',
#   'KC코트렐',
#   '상아프론테크 *',
#   '위니아딤채 *',
#   '위닉스 *',
#   '보령제약',
#   '성창오토텍 *',
#   '삼일제약',
#   '디에이치피코리아 *',
#   '안국약품 *',
#   '하츠 *',
#   '에스디생명공학 *']]

# %%
summary
# Out:
#                         테마명    전일대비 최근3일등락률(평균)    상승   보합    하락      주도주  \
# 0                       마스크  +2.51%      +4.86%  12.0  0.0  11.0      웰크론
# 1                      생명보험  +2.36%      -1.25%   3.0  1.0   2.0  미래에셋생..
# 2                    골판지 제조  +2.08%      -1.49%   5.0  0.0   7.0     대영포장
# 3                   황사/미세먼지  +1.77%      +1.31%  11.0  0.0  17.0      웰크론
# 4                        정유  +1.01%      -1.58%   2.0  0.0   1.0  SK이노베..
# 5                        광고  +0.40%      -1.15%   4.0  0.0  10.0    지어소프트
# 6              모바일솔루션(스마트폰)  +0.36%      -1.42%   6.0  1.0  12.0    키네마스터
# 7                    3D 프린터  +0.30%      -1.46%   4.0  0.0   9.0     맥스로텍
# 8                 교육/온라인 교육  +0.21%      -0.78%   7.0  1.0  15.0     메가엠디
# 9             2020 상반기 신규상장  +0.13%       0.00%   1.0  1.0   0.0  하나금융1..
# 194                    줄기세포  -3.88%      -1.36%   1.0  0.0  21.0     안트로젠
# 195          MLCC(적층세라믹콘덴서)  -4.14%      -1.45%   0.0  0.0   6.0      아모텍
# 196                    해저터널  -4.14%      -2.47%   0.0  0.0   6.0     세명전기
# 197             탄소나노튜브(CNT)  -4.15%      -2.69%   0.0  0.0   5.0    대유플러스
# 198          아스콘(아스팔트 콘크리트)  -4.24%      -1.49%   0.0  0.0   9.0     한국석유
# 199                      치매  -4.30%      -0.08%   1.0  1.0  38.0     모나리자
# 200                마리화나(대마)  -5.05%      -0.83%   0.0  0.0   4.0    뉴프라이드
# 201             구충제(펜벤다졸 등)  -5.17%      -0.63%   0.0  0.0   7.0     조아제약
# 202  백신/진단시약/방역(신종플루, AI 등)  -6.28%      +1.01%   1.0  3.0  39.0       파루
# 203              유전자 치료제/분석  -6.56%      +0.35%   2.0  0.0  21.0    지노믹트리
#
#        주도주.1                                                 링크  \
# 0       모나리자  https://finance.naver.com/sise/sise_group_deta...
# 1       동양생명  https://finance.naver.com/sise/sise_group_deta...
# 2       대림제지  https://finance.naver.com/sise/sise_group_deta...
# 3       모나리자  https://finance.naver.com/sise/sise_group_deta...
# 4      S-Oil  https://finance.naver.com/sise/sise_group_deta...
# 5      에코마케팅  https://finance.naver.com/sise/sise_group_deta...
# 6      지어소프트  https://finance.naver.com/sise/sise_group_deta...
# 7         디오  https://finance.naver.com/sise/sise_group_deta...
# 8    아이스크림..  https://finance.naver.com/sise/sise_group_deta...
# 9    케이비제2..  https://finance.naver.com/sise/sise_group_deta...
# 194     조아제약  https://finance.naver.com/sise/sise_group_deta...
# 195     삼성전기  https://finance.naver.com/sise/sise_group_deta...
# 196  KT서브마..  https://finance.naver.com/sise/sise_group_deta...
# 197    오픈베이스  https://finance.naver.com/sise/sise_group_deta...
# 198     극동유화  https://finance.naver.com/sise/sise_group_deta...
# 199      수젠텍  https://finance.naver.com/sise/sise_group_deta...
# 200  세미콘라이..  https://finance.naver.com/sise/sise_group_deta...
# 201     화일약품  https://finance.naver.com/sise/sise_group_deta...
# 202  한국콜마홀..  https://finance.naver.com/sise/sise_group_deta...
# 203     아미코젠  https://finance.naver.com/sise/sise_group_deta...
#
#                                                     종목
# 0    [웰크론 *, 모나리자, 오공 *, 케이엠 *, 메디앙스 *, 카스 *, 한송네오텍...
# 1             [미래에셋생명, 동양생명, 삼성생명, 오렌지라이프, 한화생명, 코리안리]
# 2    [대영포장, 대림제지 *, 태림포장, 수출포장, 아세아제지, 대양제지 *, 영풍제지...
# 3    [웰크론 *, 모나리자, 오공 *, 케이엠 *, 휴비츠 *, 크린앤사이언스 *, J...
# 4                                 [SK이노베이션, S-Oil, GS]
# 5    [지어소프트 *, 에코마케팅 *, 인크로스 *, 지투알, 나스미디어 *, 이엠넷 *...
# 6    [키네마스터 *, 지어소프트 *, 다날 *, 이미지스 *, 갤럭시아컴즈 *, 카페2...
# 7    [맥스로텍 *, 디오 *, 모아텍 *, 한국테크놀로지 *, 신도리코, 로보스타 *,...
# 8    [메가엠디 *, 아이스크림에듀 *, 이퓨쳐 *, NE능률 *, 메가스터디교육 *, ...
# 9                           [하나금융15호스팩 *, 케이비제20호스팩 *]
# 194  [안트로젠 *, 조아제약 *, 녹십자랩셀 *, 부광약품, 강스템바이오텍 *, 제일약...
# 195    [아모텍 *, 삼성전기, 코스모신소재, 알에프세미 *, 대주전자재료 *, 삼화콘덴서]
# 196     [세명전기 *, KT서브마린 *, 부산산업, 한국선재 *, 특수건설 *, 동아지질]
# 197              [대유플러스, 오픈베이스 *, 상보 *, 엑사이엔씨 *, 금호석유]
# 198  [한국석유, 극동유화, SG *, 엔피케이 *, 유진기업 *, 홈센타홀딩스 *, 콤...
# 199  [모나리자, 수젠텍 *, 리메드 *, 켐온 *, 종근당, 퓨쳐켐 *, 동아에스티, ...
# 200            [뉴프라이드 *, 세미콘라이트 *, 오성첨단소재 *, 에이아이비트 *]
# 201  [조아제약 *, 화일약품 *, 신풍제약, 명문제약, 알리코제약 *, 제일바이오 *,...
# 202  [파루 *, 옵티팜 *, 한국콜마홀딩스, 수젠텍 *, 엔케이맥스 *, 일양약품, 종...
# 203  [지노믹트리 *, 아미코젠 *, 코오롱생명과학 *, 헬릭스미스 *, 디엔에이링크 *...
