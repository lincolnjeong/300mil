# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
import re

# %%
def getNames(url):
    df = pd.read_html(requests.get(url).text)[2].loc[:, :'전일거래량']
    df = df[df.종목명.isna() == False]
    return [i for i in df.종목명]

# %%
def getIndustryData():
    url = 'https://finance.naver.com/sise/sise_group.nhn?type=upjong'
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    업종 = pd.read_html(html)[0].dropna().reset_index(drop=True)
    업종.columns = [i[1] for i in 업종.columns]
    업종링크 = {}
    for index, link in enumerate(soup.findAll("a", href=re.compile("^(/sise/sise_group_detail.nhn)((?!:).)*$"))):
        if 'href' in link.attrs:
            업종링크[업종.업종명[index]] = 'https://finance.naver.com' + link.attrs['href']
    업종['전일비'] = 업종.전일대비.apply(lambda x: float(x.replace('%', '')))
    업종['링크'] = 업종.업종명.apply(lambda x: 업종링크.get(x))
    업종['대표종목'] = 업종.링크.apply(lambda x: getNames(x))
    업종.sort_values('전일비', ascending=False, inplace=True)
    return pd.concat([업종.head(10), 업종.tail(10)])

# %%
getIndustryData()
# Out:
#            업종명    전일대비     전체    상승   보합    하락 등락그래프   전일비  \
# 0         전기제품  +7.19%   40.0  35.0  2.0   3.0  100%  7.19
# 1      디스플레이패널  +6.13%    2.0   1.0  0.0   1.0   85%  6.13
# 2           화학  +4.71%  110.0  87.0  3.0  20.0   65%  4.71
# 3          항공사  +4.49%   11.0  11.0  0.0   0.0   62%  4.49
# 4      전자장비와기기  +4.38%   80.0  69.0  4.0   7.0   60%  4.38
# 5   생명과학도구및서비스  +3.92%   25.0  22.0  1.0   2.0   54%  3.92
# 6         창업투자  +3.69%   15.0  13.0  1.0   1.0   51%  3.69
# 7           가구  +3.62%    9.0   7.0  0.0   2.0   50%  3.62
# 8         생물공학  +3.48%   41.0  38.0  2.0   1.0   48%  3.48
# 9         통신장비  +3.13%   48.0  39.0  7.0   2.0   43%  3.13
# 69      복합유틸리티  -0.05%    2.0   1.0  0.0   1.0    0% -0.05
# 70          식품  -0.08%   83.0  48.0  7.0  28.0    1% -0.08
# 71   상업서비스와공급품  -0.25%   23.0  17.0  0.0   6.0    3% -0.25
# 72     사무용전자제품  -0.31%    2.0   1.0  0.0   1.0    4% -0.31
# 73        가정용품  -0.39%    7.0   2.0  1.0   4.0    5% -0.39
# 74          은행  -0.42%    9.0   4.0  1.0   4.0    5% -0.42
# 75        손해보험  -0.70%   12.0   6.0  1.0   5.0    9% -0.70
# 76   에너지장비및서비스  -1.06%   10.0   4.0  3.0   3.0   14% -1.06
# 77          담배  -1.93%    1.0   0.0  0.0   1.0   26% -1.93
# 78          카드  -2.58%    1.0   0.0  0.0   1.0   35% -2.58
#
#                                                    링크  \
# 0   https://finance.naver.com/sise/sise_group_deta...
# 1   https://finance.naver.com/sise/sise_group_deta...
# 2   https://finance.naver.com/sise/sise_group_deta...
# 3   https://finance.naver.com/sise/sise_group_deta...
# 4   https://finance.naver.com/sise/sise_group_deta...
# 5   https://finance.naver.com/sise/sise_group_deta...
# 6   https://finance.naver.com/sise/sise_group_deta...
# 7   https://finance.naver.com/sise/sise_group_deta...
# 8   https://finance.naver.com/sise/sise_group_deta...
# 9   https://finance.naver.com/sise/sise_group_deta...
# 69  https://finance.naver.com/sise/sise_group_deta...
# 70  https://finance.naver.com/sise/sise_group_deta...
# 71  https://finance.naver.com/sise/sise_group_deta...
# 72  https://finance.naver.com/sise/sise_group_deta...
# 73  https://finance.naver.com/sise/sise_group_deta...
# 74  https://finance.naver.com/sise/sise_group_deta...
# 75  https://finance.naver.com/sise/sise_group_deta...
# 76  https://finance.naver.com/sise/sise_group_deta...
# 77  https://finance.naver.com/sise/sise_group_deta...
# 78  https://finance.naver.com/sise/sise_group_deta...
#
#                                                  대표종목
# 0   [피엔티 *, 삼화전기, 삼성SDI우, 에이에프더블류 *, 뉴인텍 *, 엠플러스 *...
# 1                                    [LG디스플레이, 일진디스플]
# 2   [진양폴리, 나노신소재 *, LG화학, 켐트로스 *, 와이오엠 *, KG케미칼, S...
# 3   [대한항공우, 대한항공, 티웨이홀딩스, 예림당 *, 아시아나항공, 한진칼, 제주항공...
# 4   [삼화전자, 에스디시스템 *, 이그잭스 *, 두산솔루스, 대주전자재료 *, 두산솔루...
# 5   [피씨엘 *, 랩지노믹스 *, 대한과학 *, 인트론바이오 *, 크리스탈 *, 씨젠 ...
# 6   [나우IB *, 리더스 기술투자 *, 아주IB투자 *, 린드먼아시아 *, 미래에셋벤...
# 7   [에이스침대 *, 한샘, 코아스, 지누스, 현대리바트, 에넥스, 퍼시스, 듀오백 *...
# 8   [진원생명과학, 진매트릭스 *, 바이오니아 *, 헬릭스미스 *, 티앤알바이오팹 *,...
# 9   [아이크래프트 *, 라닉스 *, 파이오링크 *, 텔콘RF제약 *, 메탈라이프 *, ...
# 69                                 [KG ETS *, 지역난방공사]
# 70  [신라에스지 *, 롯데지주우, 푸드웰 *, 서울식품우, 동원F&B, 크라운해태홀딩스...
# 71  [오르비텍 *, 제넨바이오 *, 사람인에이치알 *, KTcs, 자연과환경 *, 효성...
# 72                                   [브이티지엠피 *, 신도리코]
# 73  [애경산업, 태양 *, 바이오제네틱스 *, 메디앙스 *, 삼정펄프, 케이엠제약 *,...
# 74  [BNK금융지주, 하나금융지주, 우리금융지주, DGB금융지주, 제주은행, JB금융지...
# 75  [현대해상, DB손해보험, 한화손해보험, 흥국화재2우B, 흥국화재, 롯데손해보험, ...
# 76  [젬백스지오 *, 제이씨케미칼 *, 윌링스 *, 에스에너지 *, 에스에프씨 *, 웅...
# 77                                             [KT&G]
# 78                                             [삼성카드]

# %%
def getThemeDataPages(pageNums):
    themes = pd.DataFrame()
    linkDict = {}
    
    for pageNum in pageNums:
        url = f'https://finance.naver.com/sise/theme.nhn?&page={pageNum}'
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        
        df = pd.read_html(html)[0].reset_index(drop=True)
        df.columns = [i[1] for i in df.columns]
        df = df[df.테마명.isna() == False]
        themes = pd.concat([themes, df])
        
        # findLink
        for link in soup.findAll("a", href=re.compile("^(/sise/sise_group_detail.nhn)((?!:).)*$")):
            if 'href' in link.attrs:
                    linkDict[link.text] = 'https://finance.naver.com' + link.attrs['href']
        
    themes = themes.reset_index(drop=True)
    themes['링크'] = themes.테마명.apply(lambda x: linkDict.get(x))
    
    return themes

# %%
def getThemeData():
    url = 'https://finance.naver.com/sise/theme.nhn?&page=1'
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')

    pageNums = pd.read_html(html)[1].columns[1:]
    
    df = getThemeDataPages(pageNums)
    df['종목'] = df.링크.apply(lambda x: getNames(x))
    summary = pd.concat([df.head(10), df.tail(10)])
    return summary, df

# %%
summary, df = getThemeData()

# %%
summary
# Out:
#                   테마명    전일대비 최근3일등락률(평균)    상승   보합    하락      주도주    주도주.1  \
# 0      MLCC(적층세라믹콘덴서)  +5.38%      -1.12%   6.0  0.0   0.0  대주전자재..     삼성전기
# 1          유전자 치료제/분석  +4.75%      -3.83%  22.0  0.0   1.0  진원생명과..    랩지노믹스
# 2                2차전지  +4.67%      -0.58%  50.0  0.0   3.0     유에스티      피엔티
# 3                 창투사  +4.56%      -1.47%  14.0  0.0   1.0     나우IB  리더스 기..
# 4                 아이폰  +4.41%      -1.23%  20.0  1.0   1.0     덕우전자    삼성SDI
# 5         희귀금속(희토류 등)  +4.37%      -2.08%  10.0  0.0   2.0     삼화전자  유니온머티..
# 6                 전기차  +4.22%      -1.15%  55.0  0.0   1.0     유에스티     삼화전자
# 7    강관업체(Steel pipe)  +3.88%      -1.77%   6.0  0.0   3.0     유에스티     동양철관
# 8               면역항암제  +3.72%      -1.73%  25.0  0.0   0.0    티움바이오    에스티큐브
# 9              3D 프린터  +3.71%      -0.56%  11.0  0.0   2.0     맥스로텍      프로텍
# 194                은행  -0.06%      -0.66%   4.0  1.0   4.0  BNK금융..  하나금융지..
# 195          마리화나(대마)  -0.12%      -2.14%   3.0  0.0   1.0  오성첨단소..    뉴프라이드
# 196     2020 상반기 신규상장  -0.12%      +0.08%   0.0  1.0   1.0  케이비제2..  하나금융1..
# 197    아프리카 돼지열병(ASF)  -0.21%      -2.14%  16.0  0.0  13.0    신라에스지    이지바이오
# 198        구제역/광우병 수혜  -0.31%      -0.23%   9.0  1.0  10.0    신라에스지    이지바이오
# 199              화학섬유  -0.32%      +0.06%   5.0  0.0   3.0    코오롱인더     대한화섬
# 200              생명보험  -0.54%      +0.27%   2.0  1.0   3.0     한화생명     삼성생명
# 201         리츠(REITs)  -0.60%      +0.12%   0.0  1.0   6.0    케이탑리츠     롯데리츠
# 202               마스크  -1.12%      -2.80%  11.0  1.0  12.0  에스디생명..       오공
# 203                육계  -1.85%      +0.99%   2.0  0.0   6.0    이지바이오     팜스토리
#
#                                                     링크  \
# 0    https://finance.naver.com/sise/sise_group_deta...
# 1    https://finance.naver.com/sise/sise_group_deta...
# 2    https://finance.naver.com/sise/sise_group_deta...
# 3    https://finance.naver.com/sise/sise_group_deta...
# 4    https://finance.naver.com/sise/sise_group_deta...
# 5    https://finance.naver.com/sise/sise_group_deta...
# 6    https://finance.naver.com/sise/sise_group_deta...
# 7    https://finance.naver.com/sise/sise_group_deta...
# 8    https://finance.naver.com/sise/sise_group_deta...
# 9    https://finance.naver.com/sise/sise_group_deta...
# 194  https://finance.naver.com/sise/sise_group_deta...
# 195  https://finance.naver.com/sise/sise_group_deta...
# 196  https://finance.naver.com/sise/sise_group_deta...
# 197  https://finance.naver.com/sise/sise_group_deta...
# 198  https://finance.naver.com/sise/sise_group_deta...
# 199  https://finance.naver.com/sise/sise_group_deta...
# 200  https://finance.naver.com/sise/sise_group_deta...
# 201  https://finance.naver.com/sise/sise_group_deta...
# 202  https://finance.naver.com/sise/sise_group_deta...
# 203  https://finance.naver.com/sise/sise_group_deta...
#
#                                                     종목
# 0      [대주전자재료 *, 삼성전기, 삼화콘덴서, 알에프세미 *, 아모텍 *, 코스모신소재]
# 1    [진원생명과학, 랩지노믹스 *, 티움바이오 *, 바이오니아 *, 헬릭스미스 *, 테...
# 2    [유에스티 *, 피엔티 *, 에이에프더블류 *, 황금에스티, 두산솔루스, 엠플러스 ...
# 3    [나우IB *, 리더스 기술투자 *, 아주IB투자 *, 린드먼아시아 *, 미래에셋벤...
# 4    [덕우전자 *, 삼성SDI, LG화학, 프로텍 *, 삼성전기, LG디스플레이, 넥스...
# 5    [삼화전자, 유니온머티리얼, 유니온, 에코마이스터 *, 노바텍 *, 대원화성, LG...
# 6    [유에스티 *, 삼화전자, 삼화전기, 뉴인텍 *, 두산솔루스, 센트랄모텍, 엠플러스...
# 7    [유에스티 *, 동양철관, 삼강엠앤티 *, 휴스틸, 금강공업, 한국주철관, 하이스틸...
# 8    [티움바이오 *, 에스티큐브 *, 메드팩토 *, 헬릭스미스 *, 인콘 *, 크리스탈...
# 9    [맥스로텍 *, 프로텍 *, 티앤알바이오팹 *, 에스티아이 *, 디오 *, 하이비젼...
# 194  [BNK금융지주, 하나금융지주, 우리금융지주, DGB금융지주, 제주은행, JB금융지...
# 195            [오성첨단소재 *, 뉴프라이드 *, 에이아이비트 *, 세미콘라이트 *]
# 196                         [케이비제20호스팩 *, 하나금융15호스팩 *]
# 197  [신라에스지 *, 이지바이오 *, 코미팜 *, 한일사료 *, 대한뉴팜 *, 고려시멘...
# 198  [신라에스지 *, 이지바이오 *, 동원산업, 한일사료 *, 사조산업, 팜스토리 *,...
# 199  [코오롱인더, 대한화섬, 성안, 코오롱머티리얼, 효성티앤씨, 태광산업, 티케이케미칼...
# 200           [한화생명, 삼성생명, 오렌지라이프, 코리안리, 동양생명, 미래에셋생명]
# 201  [케이탑리츠, 롯데리츠, NH프라임리츠, 이리츠코크렙, 에이리츠, 신한알파리츠, 모...
# 202  [에스디생명공학 *, 오공 *, 녹십자엠에스 *, 애경산업, 카스 *, 일동제약, ...
# 203  [이지바이오 *, 팜스토리 *, 동우팜투테이블 *, 마니커에프앤지 *, 하림 *, ...

# %%
상장법인목록 = pd.read_excel('./상장법인목록/상장법인목록.xlsx')

# %%
def 종목조회(종목명):
    종목코드 = str(상장법인목록[상장법인목록.회사명 == 종목명].종목코드.values[0])
    if len(종목코드) < 6:
        종목코드 = '0' + 종목코드
    url = 'https://finance.naver.com/item/frgn.nhn?code=' + 종목코드
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
#     print(soup.prettify())
    return pd.read_html(html)[7]
종목조회('NAVER')
# Out:
# 035420
#                   0                  1
# 0  PERlEPS(FnGuide)  45.85배  l  3,937원
# 1      PERlEPS(KRX)  40.68배  l  4,437원
# 2         추정PERlEPS  40.00배  l  4,568원
# 3  PBRlBPS(FnGuide)     ∞배  l  35,847원
# 4             배당수익률                NaN

# %%
def 금():
    url = 'https://finance.naver.com/marketindex/goldDetail.nhn#'
    html = requests.get(url).text
#     print(soup.prettify())
    return pd.read_html(html)[1]
금()
# Out:
#                  구분         현재가
# 0       계좌 (고객입금 시)  60,453.41원
# 1       계좌 (고객출금 시)  59,256.33원
# 2      실물 (고객이 살 때)  62,847.61원
# 3       실물 (고객이팔 때)  56,862.13원
# 4  기준 국제 금 (트로이 온스)  1,567.90달러
# 5         기준 원달러 환율   1,187.50원
